# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 02 – Feature Engineering\n",
    "\n",
    "This notebook explores simple feature engineering strategies for posture\n",
    "classification, such as aggregated pressure features and balance ratios.\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "\n",
    "df = pd.read_csv(\"../data/sample_posture_data.csv\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Aggregated features\n",
    "df[\"sum_front\"] = df[\"sensor_front_left\"] + df[\"sensor_front_right\"]\n",
    "df[\"sum_back\"] = df[\"sensor_back_left\"] + df[\"sensor_back_right\"]\n",
    "\n",
    "# Total pressure\n",
    "df[\"total_pressure\"] = (\n",
    "    df[\"sensor_front_left\"]\n",
    "    + df[\"sensor_front_right\"]\n",
    "    + df[\"sensor_back_left\"]\n",
    "    + df[\"sensor_back_right\"]\n",
    "    + df[\"sensor_middle\"]\n",
    ")\n",
    "\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Balance / symmetry features\n",
    "df[\"left_minus_right\"] = (\n",
    "    df[\"sensor_front_left\"] + df[\"sensor_back_left\"]\n",
    "    - df[\"sensor_front_right\"] - df[\"sensor_back_right\"]\n",
    ")\n",
    "\n",
    "df[\"front_minus_back\"] = (\n",
    "    df[\"sensor_front_left\"] + df[\"sensor_front_right\"]\n",
    "    - df[\"sensor_back_left\"] - df[\"sensor_back_right\"]\n",
    ")\n",
    "\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Check correlations with new features\n",
    "corr = df.drop(columns=[\"label\"]).corr()\n",
    "corr[\"total_pressure\"].sort_values(ascending=False)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# (Optional) Save engineered dataset\n",
    "df.to_csv(\"../data/sample_posture_data_engineered.csv\", index=False)\n",
    "print(\"Saved engineered dataset to ../data/sample_posture_data_engineered.csv\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
