# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 05 – Noise Reduction & Outlier Analysis\n",
    "\n",
    "This notebook demonstrates the effect of:\n",
    "\n",
    "- Noise reduction using a simple rolling mean\n",
    "- Outlier removal using DBSCAN clustering\n",
    "\n",
    "on the posture dataset."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import seaborn as sns\n",
    "import matplotlib.pyplot as plt\n",
    "import sys\n",
    "from pathlib import Path\n",
    "\n",
    "# Add src/ to the Python path so we can import our own preprocessing modules\n",
    "project_root = Path(\"..\").resolve()\n",
    "src_path = project_root / \"src\"\n",
    "sys.path.append(str(src_path))\n",
    "\n",
    "from preprocessing.noise_reduction import reduce_noise\n",
    "from preprocessing.dbscan_outlier_removal import remove_outliers_dbscan\n",
    "\n",
    "# Load dataset\n",
    "df = pd.read_csv(\"../data/sample_posture_data.csv\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Visualise raw data\n",
    "sns.pairplot(df, hue=\"label\")\n",
    "plt.suptitle(\"Raw Data – Sensor Distributions\", y=1.02)\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Apply noise reduction (rolling mean)\n",
    "df_smooth = reduce_noise(df, window_size=2)\n",
    "sns.pairplot(df_smooth, hue=\"label\")\n",
    "plt.suptitle(\"After Noise Reduction (window=2)\", y=1.02)\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Apply DBSCAN outlier removal\n",
    "df_clean = remove_outliers_dbscan(df_smooth, eps=0.25, min_samples=2)\n",
    "df_clean.shape, df.shape"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Visualise cleaned data\n",
    "sns.pairplot(df_clean, hue=\"label\")\n",
    "plt.suptitle(\"After Outlier Removal (DBSCAN)\", y=1.02)\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
